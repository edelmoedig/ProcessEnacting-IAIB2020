# %% [markdown]
# <a href="https://colab.research.google.com/github/edelmoedig/ProcessEnacting-IAIB2020/blob/master/Lab02_2021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This lab assumes that the student has basic knowledge of Python. If not, please go to http://www.learnpython.org and go through the interactive tutorials.

# %% [markdown]
# ## Reading files using a specified codec
#
# First, we'll study how to read content from text file.
#
# We learned in the lecture that it's important to know the text codec that is used to encode the characters, when reading text from files. This can be done using the codecs package.
#
# You can the sample text from here: https://phon.ioc.ee/~tanela/parasiitlusest.txt but you are encouraged to use any other Estonian text.

# %%
# !wget https://phon.ioc.ee/~tanela/parasiitlusest.txt
# Out:
# --2021-02-02 10:25:11--  https://phon.ioc.ee/~tanela/parasiitlusest.txt
# Resolving phon.ioc.ee (phon.ioc.ee)... 193.40.251.126
# Connecting to phon.ioc.ee (phon.ioc.ee)|193.40.251.126|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4496 (4.4K) [text/plain]
# Saving to: ‘parasiitlusest.txt’
#
# parasiitlusest.txt  100%[===================>]   4.39K  --.-KB/s    in 0s
#
# 2021-02-02 10:25:13 (153 MB/s) - ‘parasiitlusest.txt’ saved [4496/4496]

# %%
import codecs

# %%
f = codecs.open('parasiitlusest.txt', 'r', 'utf-8')

# %% [markdown]
# The arguments correspond to file name, mode ('r' stands for 'read'), and the codec.
#
# The returned variable `f` is a file handle. It doesn't contain the file contents, it's just a pointer to the file in the filesystem.
#
# There are a number of ways to read the text from the text file. One of the simplest is the following:

# %%
lines = f.readlines()

# %%
print(lines)
# Out:
# ['Parasiitlus on teiste energiast toitumine ilma, et midagi samaväärset vastu antaks ehk saamahimu üks väljendusvorme. Parasiitluse vastand on taimeriigis levinud sümbioos (botaanikas tuntud mõiste), kus toimub vastastikku kasulik kaubavahetus.\r\n', 'Parasiitlus on hingestatud isikutele paratamatu ehk ülivajalik õppetund, mis hakkab pihta juba ainuraksetel loomadel viiruste ja bakterite näol ja maise inimhinge tasandil lõpeb paralleelmaailmade valgete draakonite (kõrgtasandi reptiloidide = keha + mõistus, hing puudub) pakutavate manipulatsioonide tundmaõppimisega.\r\n', 'Selleks et õppetund oleks täiuslik, korraldab elu olukorrad, kus ollakse kord ise parasiit, kord ollakse parasiidi ohver. Kuni inimeses on tahtmine teiste seljas liugu lasta, tõmbab ta endale ligi (vastavalt magnetismi seadusele) parasiite, kannatades ise ja pannes teisi kannatama. Õppetunni lõppeesmärgina peab inimene teadvustama, et ta teadlikult tasakaalustab saadu millegi sama väärtuslikuga.\r\n', 'Parasiitluse üks erivorme on vampiirlus, kus energia imemine toimub füüsilist kontakti omamata, kasutades selleks peenmateriaalseid struktuure. Ainuke abi vampiirile on mitte lasta tal teie üle võimutseda – et ta õpiks ise energiat tootma. Vampiir on läinud elus lihtsama vastupanu teed. Selle asemel, et ise energiat toota või tootmisprotsessis osaleda, on ta teinud otsuse talle vajalikku energia varastada. Lihtsama vastupanu teed minemine on alati raskem tee. Sellel lihtsal põhjusel, et endale võetud õppetunnid tuleb omandada niikuinii pluss katsumused, mis saadakse sellel nn. lihtsal teel. Sellest momendist, kui inimene on teinud otsuse lihtsama vastupanu teed minna, hakkab ta hingel raske – ta on läinud oma südame-tunnistusega vastuollu. Südametunnistusega vastuollu minek on hinge eitamine. Seda mida pole, seda on lihtne ära anda. Seda teadmist kasutab ära orjandussüsteem, meelitades inimesi oma hingest loobuma. See, kes oma hingeosa ära on andnud, loobub paratamatult ka oma tegutsemise jõust. See, kes on jõuetu, ei suuda enam oma probleeme lahendada ehk ta on oma probleemide ees jõuetu.\r\n', 'Vampiir ei saa õnnelik olla, kuna ta on ennast ise loomingust välja lülitanud. Looming tähendab isetegemist ja selle kaudu oma isiksuse arendamist. Kui teistelt energiat valmiskujul võetakse, siis enda sees olevad energia tootmissüsteemid jäävad tööta ja manduvad. Mida kauem inimvampiir tegutseb, seda suuremasse sõltuvusse ta teiste inimeste energiast jääb. Lõpuks on tema eesmärgiks ja pidevaks tegutsemisliiniks probleem, kuidas teistelt energiat kätte saada. Teda ei huvita see, mis ohvrist saab – peaasi et oma eluks vajaliku portsu energiat kätte saaks. \r\n', 'Üks võimsamaid ja salakavalamaid vampirismisüsteeme, mille kaudu toituvad paralleelmaailmade ja dimensioonide isendid, on kõikvõimalikud religiooni-süsteemid, mis meelitavad inimesi oma mõistust eitama ja jumala ülemuslikkust tunnistama. Inimene, kes oma mõistusest  loobub  ja  teiste  oma  paremaks peab või kes alahindab oma mõistust ja sellega laseb teistel enda üle võimutseda ja lõpuks võitlusest loobub ehk võimutsejaid eitama hakkab, avab endale tee kiilaspäisusele. Inimene, kes ei julge oma saatust ehk neid õppetunde, mis ta enne kehastumist valis,  vastu võtta ja kaldub kergema vastupanu teele – selle juuksed langevad pöörise kohalt välja. Sellega jääb ta ilma (kaotab sideme) oma elutee vaimsete õpetajate juhendamisest ja elu ülendavast poolest ehk õnnest. Ta peab endale vajalikku ülendavat energiat teistelt varastama ehk teiste kallal vampiiritsema. Kui ohvrilt ülendav ehk ülestõstev energia pihta pannakse, hakkab tal füüsiliselt raske ja ta tunneb end maadligi litsutuna.\r\n', 'Inimene, kes kõigi teiste inimeste (rääkimata füüsilisele silmaga nähtamatute tegelaste olemasolust) vaimsust eitama hakkab, kaotab kõik juuksed. Temast on saanud puhtmaterialistliku maailmavaatega kodanik. Ta püüab teistele tõestada, et ta on hirmus vaimne. Paraku vajab tõestamist vaid see, mida pole. Kui kiilakas kirikupapp tei ...

# %% [markdown]
# Note that each line in the file ends with a newline character (except for the last, possibly). So each element in `lines` array also ends in a new line. Often it's beneficial to get rid of the line-ending new-lines. This can be accomplished like this:

# %%
f = codecs.open('parasiitlusest.txt', 'r', 'utf-8')
lines = [l.strip() for l in f.readlines()]

# %%
print(lines[0])
# Out:
# Parasiitlus on teiste energiast toitumine ilma, et midagi samaväärset vastu antaks ehk saamahimu üks väljendusvorme. Parasiitluse vastand on taimeriigis levinud sümbioos (botaanikas tuntud mõiste), kus toimub vastastikku kasulik kaubavahetus.

# %% [markdown]
# Note that we had to reopen the file in order to call `readlines()` on `f` again.
#
# ## List comprehension
#
# The line-end stripping was implemented using a Python construct called list comprehension. It's incredibly useful when working with all kind of data. It makes it easy to apply a certain function to all elements of a list and filter list elements. Some examples in the following.

# %%
[l.upper() for l in lines][0:2]
# Out:
# ['PARASIITLUS ON TEISTE ENERGIAST TOITUMINE ILMA, ET MIDAGI SAMAVÄÄRSET VASTU ANTAKS EHK SAAMAHIMU ÜKS VÄLJENDUSVORME. PARASIITLUSE VASTAND ON TAIMERIIGIS LEVINUD SÜMBIOOS (BOTAANIKAS TUNTUD MÕISTE), KUS TOIMUB VASTASTIKKU KASULIK KAUBAVAHETUS.',
#  'PARASIITLUS ON HINGESTATUD ISIKUTELE PARATAMATU EHK ÜLIVAJALIK ÕPPETUND, MIS HAKKAB PIHTA JUBA AINURAKSETEL LOOMADEL VIIRUSTE JA BAKTERITE NÄOL JA MAISE INIMHINGE TASANDIL LÕPEB PARALLEELMAAILMADE VALGETE DRAAKONITE (KÕRGTASANDI REPTILOIDIDE = KEHA + MÕISTUS, HING PUUDUB) PAKUTAVATE MANIPULATSIOONIDE TUNDMAÕPPIMISEGA.']

# %%
[len(l) for l in lines][0:5]
# Out:
# [242, 319, 398, 1106, 560]

# %% [markdown]
# It's also easy to filter lists:

# %%
[l for l in lines if len(l) > 1000]
# Out:
# ['Parasiitluse üks erivorme on vampiirlus, kus energia imemine toimub füüsilist kontakti omamata, kasutades selleks peenmateriaalseid struktuure. Ainuke abi vampiirile on mitte lasta tal teie üle võimutseda – et ta õpiks ise energiat tootma. Vampiir on läinud elus lihtsama vastupanu teed. Selle asemel, et ise energiat toota või tootmisprotsessis osaleda, on ta teinud otsuse talle vajalikku energia varastada. Lihtsama vastupanu teed minemine on alati raskem tee. Sellel lihtsal põhjusel, et endale võetud õppetunnid tuleb omandada niikuinii pluss katsumused, mis saadakse sellel nn. lihtsal teel. Sellest momendist, kui inimene on teinud otsuse lihtsama vastupanu teed minna, hakkab ta hingel raske – ta on läinud oma südame-tunnistusega vastuollu. Südametunnistusega vastuollu minek on hinge eitamine. Seda mida pole, seda on lihtne ära anda. Seda teadmist kasutab ära orjandussüsteem, meelitades inimesi oma hingest loobuma. See, kes oma hingeosa ära on andnud, loobub paratamatult ka oma tegutsemise jõust. See, kes on jõuetu, ei suuda enam oma probleeme lahendada ehk ta on oma probleemide ees jõuetu.']

# %%
[l for l in lines if l.startswith('V')]
# Out:
# ['Vampiir ei saa õnnelik olla, kuna ta on ennast ise loomingust välja lülitanud. Looming tähendab isetegemist ja selle kaudu oma isiksuse arendamist. Kui teistelt energiat valmiskujul võetakse, siis enda sees olevad energia tootmissüsteemid jäävad tööta ja manduvad. Mida kauem inimvampiir tegutseb, seda suuremasse sõltuvusse ta teiste inimeste energiast jääb. Lõpuks on tema eesmärgiks ja pidevaks tegutsemisliiniks probleem, kuidas teistelt energiat kätte saada. Teda ei huvita see, mis ohvrist saab – peaasi et oma eluks vajaliku portsu energiat kätte saaks.']

# %% [markdown]
# ## Regular expressions
# Now, let's check how regular expressions can be used in Python.
#
# The most important functions for working with regular expressions are `match`, `sub`, `findall` ja `split`, all from the `re` Python package.

# %%
import re

# %%
numbers = re.findall("\d+", "I have 22 dogs and 6 cats")

# %%
print(numbers)
# Out:
# ['22', '6']

# %% [markdown]
# The `findall` function can be used as a very simple tokenizer. E.g., let's find all matches that consists exclusivey of "word" characters.

# %%
words = re.findall("\w+", "I have 22 dogs and 6 cats. I love animals.")
print(words)
# Out:
# ['I', 'have', '22', 'dogs', 'and', '6', 'cats', 'I', 'love', 'animals']

# %% [markdown]
# Since Python 3, the `\w` character class also works for non-ASCII characters:

# %%
re.findall("\w+", "Ülol on kaks õuna ja kolm garaaži")
# Out:
# ['Ülol', 'on', 'kaks', 'õuna', 'ja', 'kolm', 'garaaži']

# %% [markdown]
# An alternative way to perform tokenization is to use the `re.split()` method. In this case, we have to specify a regular expression that defines places where words are split:

# %%
re.split("[\s,.!?]+", "I have 22 dogs and 6 cats. I love animals.")
# Out:
# ['I', 'have', '22', 'dogs', 'and', '6', 'cats', 'I', 'love', 'animals', '']

# %% [markdown]
# Note that this results in an empty element at the end of the token list. This is because `re.split()` splits on the last ".", and puts the resulting empty string on the right also to the result. But it's easy to fix this using list comprehension:

# %%
[token for token in re.split("[\s,.!?]+", "I have 22 dogs and 6 cats. I love animals.") if len(token) > 0]
# Out:
# ['I', 'have', '22', 'dogs', 'and', '6', 'cats', 'I', 'love', 'animals']

# %% [markdown]
# Another useful regexp method is `match()`. It checks whether the given start of the given string matches a regexp. If yes, a Match object is returned that contans information about the match. If there is no match, `None` is returned.

# %%
m = re.match("Tallinn?", "Tallinnas sadas lund.")
if m:
    print(m.group(0))
# Out:
# Tallinn

# %% [markdown]
# Retrieving the match groups is one of the most useful functionalities of the `match()` method:

# %%
m = re.match("(.+), (\d{5}) (Tallinn|Tartu)", "Akadeemia tee 21, 10126 Tallinn")
if m:
    print(m.group(1))
    print(m.group(2))
    print(m.group(3))
# Out:
# Akadeemia tee 21
# 10126
# Tallinn

# %% [markdown]
# The `match()` function checks whether the start of the string matches the rexexp. If you want to check whether the full string matches the regexp, just add the "line end anchor" to the end of the regexp:

# %%
if re.match("\d+", "12345 foo"): 
    print("Match!") 
else: 
    print("No match")
# Out:
# Match!

# %%
if re.match("\d+$", "12345 foo"): 
    print("Match!") 
else: 
    print("No match")
# Out:
# No match

# %% [markdown]
# For regexp-based substitution, the `re.sub()` function can be used:

# %%
email_address = "Please contact us at: xyz@foo.com"
new_email_address = re.sub(r'([\w\.-]+)@([\w\.-]+)', r'support@foo.com', email_address)
print(new_email_address)
# Out:
# Please contact us at: support@foo.com

# %% [markdown]
# The `sub()` method allows using back-references. But in this case it's useful to specify the replacement string using the r'string' method (raw string), otherwise the `\1` element will be interpreted as "character with ASCII code 1" by Python:

# %%
email_address = "Please contact us at: info@nordea.ee"
new_email_address = re.sub('([\w\.-]+)@nordea.ee', r'\1@luminor.ee', email_address)
print(new_email_address)
# Out:
# Please contact us at: info@luminor.ee

# %% [markdown]
# ## spaCy
#
# SpaCy is a free, open-source library for advanced Natural Language Processing (NLP) in Python. It's a bit similar to EstNLTK, but has a different API, and covers more languages. It is highly recommended when working with English texts. See https://spacy.io/usage/spacy-101

# %% [markdown]
# For installation instructions of spaCy, see https://spacy.io/usage/.
#
# Spacy 3.0 was released just a few days ago (at the time of writing this notebook). Therefore, it is not yet available at Google Colab by default. However, we can upgrade spacy manually using pip:

# %%
! pip install -U pip setuptools wheel
! pip install -U spacy

# %%
import spacy
print(spacy.__version__)
# Out:
# 3.0.0

# %% [markdown]
# In order to process language, spacy also needs a model for that language. The list of available models is here: https://spacy.io/usage/models
#
# Let's download the English model:

# %%
! python -m spacy download en_core_web_sm
# Out:
# 2021-02-02 10:36:28.166639: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# Collecting en-core-web-sm==3.0.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.0.0/en_core_web_sm-3.0.0-py3-none-any.whl (13.7 MB)
#      |████████████████████████████████| 13.7 MB 77.9 MB/s
# Requirement already satisfied: spacy<3.1.0,>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from en-core-web-sm==3.0.0) (3.0.0)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.3.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.6/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (20.8)
# Requirement already satisfied: pathy in /usr/local/lib/python3.6/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.3.4)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.19.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.0.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.23.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (53.0.0)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.4.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.6/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.8.1)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.6/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.4.0)
# Requirement already satisfied: thinc<8.1.0,>=8.0.0 in /usr/local/lib/python3.6/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (8.0.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.5)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.1)
# Requirement already satisfied: pydantic<1.8.0,>=1.7.1 in /usr/local/lib/python3.6/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.7.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.4.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.6/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.11.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (4.41.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.5)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.6/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.4.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.4.7)
# Requirement already satisfied: dataclasses>=0.6 in /usr/local/lib/python3.6/dist-packages (from pydantic<1.8.0,>=1.7.1->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.4)
# Requirement already satisfied: contextvars<3,>=2.4 in /usr/local/lib/python3.6/dist-packages (from thinc<8.1.0,>=8.0.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.4)
# Requirement already satisfied: immutables>=0.9 in /usr/local/lib/python3.6/dist-packages (from contextvars<3,>=2.4->thinc<8.1.0,>=8.0.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.14)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /usr/local/lib/python3.6/dist-packages (from typer<0.4.0,>=0.3.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from jinja2->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.1.1)
# Requirement already satisfied: smart-open<4.0.0,>=2.2.0 in /usr/local/lib/python3.6/dist-packages (from pathy->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.0)
# Installing collected packages: en-core-web-sm
#   Attempting uninstall: en-core-web-sm
#     Found existing installation: en-core-web-sm 2.2.5
#     Uninstalling en-core-web-sm-2.2.5:
#       Successfully uninstalled en-core-web-sm-2.2.5
# Successfully installed en-core-web-sm-3.0.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# Now we start processing text. I recommend you to follow the excellent short tutorial at https://spacy.io/usage/spacy-101.

# %%
doc = nlp(u'Apple is looking at buying U.K. startup for $1 billion')
for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
          token.shape_, token.is_alpha, token.is_stop)
# Out:
# Apple Apple PROPN NNP nsubj Xxxxx True False
# is be AUX VBZ aux xx True True
# looking look VERB VBG ROOT xxxx True False
# at at ADP IN prep xx True True
# buying buy VERB VBG pcomp xxxx True False
# U.K. U.K. PROPN NNP dobj X.X. False False
# startup startup NOUN NN advcl xxxx True False
# for for ADP IN prep xxx True True
# $ $ SYM $ quantmod $ False False
# 1 1 NUM CD compound d False False
# billion billion NUM CD pobj xxxx True False

# %% [markdown]
# ### Named entity recognition
#
# SpaCy can also do named entity recognition:

# %%
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# Apple 0 5 ORG
# U.K. 27 31 GPE
# $1 billion 44 54 MONEY

# %% [markdown]
# Named entites can be nicely visualized using spaCy's displaCy library:

# %%
from spacy import displacy

# %%
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is looking at buying
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.K.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  startup for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $1 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# </div></span>

# %% [markdown]
# ## Stanza
#
# Stanford has also a very nice open source NLP library called Stanza. The nice thing about this is that it supports much m ore languages than spaCy -- more than 60 in total. Estonian is among the supported languages.
#
# Is your native language supported? See https://stanfordnlp.github.io/stanza/available_models.html.
#
# Let's install Stanza and explore what it can do.

# %%
! pip install stanza
# Out:
# Collecting stanza
#   Downloading stanza-1.2-py3-none-any.whl (282 kB)
#      |████████████████████████████████| 282 kB 4.3 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from stanza) (1.19.5)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.6/dist-packages (from stanza) (1.7.0+cu101)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.6/dist-packages (from stanza) (3.12.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from stanza) (4.41.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from stanza) (2.23.0)
# Requirement already satisfied: dataclasses in /usr/local/lib/python3.6/dist-packages (from torch>=1.3.0->stanza) (0.8)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch>=1.3.0->stanza) (0.16.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from torch>=1.3.0->stanza) (3.7.4.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf->stanza) (53.0.0)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.6/dist-packages (from protobuf->stanza) (1.15.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->stanza) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->stanza) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->stanza) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->stanza) (2.10)
# Installing collected packages: stanza
# Successfully installed stanza-1.2

# %%
import stanza

# %% [markdown]
# We'll experiment with Estonian models. Feel free to choose any other supported language. The language codes can be seen here: https://stanfordnlp.github.io/stanza/available_models.html

# %%
stanza.download('et')
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/master/resources_1.2.0.json: 128kB [00:00, 31.7MB/s]
# 2021-02-02 10:44:38 INFO: Downloading default packages for language: et (Estonian)...
# Downloading http://nlp.stanford.edu/software/stanza/1.2.0/et/default.zip: 100%|██████████| 212M/212M [00:31<00:00, 6.76MB/s]
# 2021-02-02 10:45:13 INFO: Finished downloading models and saved to /root/stanza_resources.

# %%
nlp = stanza.Pipeline(lang="et")
# Out:
# 2021-02-02 10:45:31 INFO: Loading these models for language: et (Estonian):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | edt     |
# | pos       | edt     |
# | lemma     | edt     |
# | depparse  | edt     |
# =======================
#
# 2021-02-02 10:45:31 INFO: Use device: cpu
# 2021-02-02 10:45:31 INFO: Loading: tokenize
# 2021-02-02 10:45:31 INFO: Loading: pos
# 2021-02-02 10:45:31 INFO: Loading: lemma
# 2021-02-02 10:45:31 INFO: Loading: depparse
# 2021-02-02 10:45:32 INFO: Done loading processors!

# %% [markdown]
# We'll use the first line of the text file we loaded above:

# %%
text = lines[0]
print(text)
# Out:
# Parasiitlus on teiste energiast toitumine ilma, et midagi samaväärset vastu antaks ehk saamahimu üks väljendusvorme. Parasiitluse vastand on taimeriigis levinud sümbioos (botaanikas tuntud mõiste), kus toimub vastastikku kasulik kaubavahetus.

# %%
doc = nlp(text)

# %% [markdown]
# The `doc` object is now a list of sentences, which in turn are lists of words. Let's look at the first sentence:

# %%
doc.sentences[0].print_tokens()
# Out:
# <Token id=1;words=[<Word id=1;text=Parasiitlus;lemma=parasiitlus;upos=NOUN;xpos=S;feats=Case=Nom|Number=Sing;head=5;deprel=nsubj:cop>]>
# <Token id=2;words=[<Word id=2;text=on;lemma=olema;upos=AUX;xpos=V;feats=Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act;head=5;deprel=cop>]>
# <Token id=3;words=[<Word id=3;text=teiste;lemma=teine;upos=PRON;xpos=P;feats=Case=Gen|Number=Plur|PronType=Dem;head=4;deprel=nmod>]>
# <Token id=4;words=[<Word id=4;text=energiast;lemma=energia;upos=NOUN;xpos=S;feats=Case=Ela|Number=Sing;head=5;deprel=nmod>]>
# <Token id=5;words=[<Word id=5;text=toitumine;lemma=toitumine;upos=NOUN;xpos=S;feats=Case=Nom|Number=Sing;head=0;deprel=root>]>
# <Token id=6;words=[<Word id=6;text=ilma;lemma=ilma;upos=ADV;xpos=D;head=5;deprel=advmod>]>
# <Token id=7;words=[<Word id=7;text=,;lemma=,;upos=PUNCT;xpos=Z;head=12;deprel=punct>]>
# <Token id=8;words=[<Word id=8;text=et;lemma=et;upos=SCONJ;xpos=J;head=12;deprel=mark>]>
# <Token id=9;words=[<Word id=9;text=midagi;lemma=miski;upos=PRON;xpos=P;feats=Case=Par|Number=Sing|PronType=Ind;head=12;deprel=obj>]>
# <Token id=10;words=[<Word id=10;text=samaväärset;lemma=sama_väärne;upos=ADJ;xpos=A;feats=Case=Par|Degree=Pos|Number=Sing;head=9;deprel=amod>]>
# <Token id=11;words=[<Word id=11;text=vastu;lemma=vastu;upos=ADV;xpos=D;head=12;deprel=compound:prt>]>
# <Token id=12;words=[<Word id=12;text=antaks;lemma=andma;upos=VERB;xpos=V;feats=Mood=Cnd|Tense=Pres|VerbForm=Fin|Voice=Act;head=5;deprel=advcl>]>
# <Token id=13;words=[<Word id=13;text=ehk;lemma=ehk;upos=ADV;xpos=D;head=12;deprel=advmod>]>
# <Token id=14;words=[<Word id=14;text=saamahimu;lemma=saama_himu;upos=NOUN;xpos=S;feats=Case=Gen|Number=Sing;head=16;deprel=nmod>]>
# <Token id=15;words=[<Word id=15;text=üks;lemma=üks;upos=DET;xpos=P;feats=Case=Nom|Number=Sing|PronType=Ind;head=16;deprel=nummod>]>
# <Token id=16;words=[<Word id=16;text=väljendusvorme;lemma=väljendus_vorm;upos=NOUN;xpos=S;feats=Case=Par|Number=Plur;head=12;deprel=nsubj>]>
# <Token id=17;words=[<Word id=17;text=.;lemma=.;upos=PUNCT;xpos=Z;head=5;deprel=punct>]>

# %% [markdown]
# It's easy to extract the word and it's lemma, and a POS (part-of-speech, i.e., word type) tag:

# %%
for i, sentence in enumerate(doc.sentences):
  print("-----------------")
  print("Sentence %d" % i)
  for word in sentence.words:
    print("%16s %16s %5s" % (word.text, word.lemma, word.upos))
# Out:
# -----------------
# Sentence 0
#      Parasiitlus      parasiitlus  NOUN
#               on            olema   AUX
#           teiste            teine  PRON
#        energiast          energia  NOUN
#        toitumine        toitumine  NOUN
#             ilma             ilma   ADV
#                ,                , PUNCT
#               et               et SCONJ
#           midagi            miski  PRON
#      samaväärset      sama_väärne   ADJ
#            vastu            vastu   ADV
#           antaks            andma  VERB
#              ehk              ehk   ADV
#        saamahimu       saama_himu  NOUN
#              üks              üks   DET
#   väljendusvorme   väljendus_vorm  NOUN
#                .                . PUNCT
# -----------------
# Sentence 1
#     Parasiitluse      parasiitlus  NOUN
#          vastand          vastand  NOUN
#               on            olema   AUX
#      taimeriigis       taime_riik  NOUN
#          levinud          levinud   ADJ
#         sümbioos         sümbioos  NOUN
#                (                ( PUNCT
#       botaanikas        botaanika  NOUN
#           tuntud           tuntud   ADJ
#           mõiste           mõiste  NOUN
#                )                ) PUNCT
#                ,                , PUNCT
#              kus              kus   ADV
#           toimub          toimuma  VERB
#      vastastikku      vastastikku   ADV
#          kasulik          kasulik   ADJ
#     kaubavahetus    kauba_vahetus  NOUN
#                .                . PUNCT

# %% [markdown]
# Stanza can also perform named entity recognition, but not for all languages. Estonian models do not support named entity recognition yet.
#
# Let's try NER with English models:

# %%
stanza.download('en')
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/master/resources_1.2.0.json: 128kB [00:00, 31.6MB/s]
# 2021-02-02 10:53:05 INFO: Downloading default packages for language: en (English)...
# Downloading http://nlp.stanford.edu/software/stanza/1.2.0/en/default.zip: 100%|██████████| 411M/411M [00:29<00:00, 14.1MB/s]
# 2021-02-02 10:53:45 INFO: Finished downloading models and saved to /root/stanza_resources.

# %%
nlp = stanza.Pipeline(lang='en', processors='tokenize,ner')
# Out:
# 2021-02-02 11:02:13 INFO: Loading these models for language: en (English):
# =========================
# | Processor | Package   |
# -------------------------
# | tokenize  | combined  |
# | ner       | ontonotes |
# =========================
#
# 2021-02-02 11:02:13 INFO: Use device: cpu
# 2021-02-02 11:02:13 INFO: Loading: tokenize
# 2021-02-02 11:02:13 INFO: Loading: ner
# 2021-02-02 11:02:14 INFO: Done loading processors!

# %%
doc = nlp('Apple is looking at buying U.K. startup for $1 billion')

# %%
print(*[f'entity: {ent.text}\ttype: {ent.type}' for ent in doc.ents], sep='\n')
# Out:
# entity: Apple	type: ORG
# entity: U.K.	type: GPE
# entity: $1 billion	type: MONEY
